# %%
from analyse import data, calculate, transform, plot
import ideal_markets as ideal

# %%
tickers = data.get_tickers()
ticks = [10,50]

short = 12
long = 24
signal = 9

res = ideal.by_crossing_emas(tickers, "1w", ticks)
for name, df in res:
    print(name)
    plot.emas(df, ticks)
    transform.insert_macd_oscilator(df, short, long, signal)
    plot.macd(df, short, long, signal)
# Out:
# BTCUSDT
# ETHUSDT
# SOLUSDT
# XRPUSDT
# LINKUSDT
