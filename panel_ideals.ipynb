# %%
from plot import plot_emas, plot_momentum
from main import get_tickers
from main import momentum_oscilator
import ideal_markets as ideal

# %%
tickers = get_tickers()
ticks = [10,50]
res = ideal.by_crossing_emas(tickers, "1w", ticks)
for name, df in res:
    print(name)
    plot_emas(df, ticks)
    n = 4
    momentum = momentum_oscilator(df, n)
    df[f"{n}_momentum"] = momentum
    plot_momentum(df, n)
# Out:
# BTCUSDT
# SOLUSDT
# XRPUSDT
# LINKUSDT

# %%
tickers = get_tickers()
ticks = [10,50]
res = ideal.by_crossing_emas(tickers, "1d", ticks)
for name, df in res:
    print(name)
    plot_emas(df, ticks)
    n = 10
    momentum = momentum_oscilator(df, n)
    df[f"{n}_momentum"] = momentum
    plot_momentum(df, n)
# Out:
# BTCUSDT
# ETHUSDT
# SOLUSDT
# XRPUSDT
# DOGEUSDT
# ADAUSDT
# BNBUSDT
# LINKUSDT

# %%
tickers = get_tickers()
ticks = [10,50]
res = ideal.by_crossing_emas(tickers, "1h", ticks)
for name, df in res:
    print(name)
    plot_emas(df, ticks)
    n = 10
    momentum = momentum_oscilator(df, n)
    df[f"{n}_momentum"] = momentum
    plot_momentum(df, n)
# Out:
# BTCUSDT
# ETHUSDT
# SOLUSDT
# XRPUSDT
# DOGEUSDT
# ADAUSDT
# LINKUSDT
