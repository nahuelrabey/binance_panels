# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import timedelta
from main import get_data_as_df, momentum_oscilator, get_tickers
from plot import plot_momentum
import ideal_markets as ideals

# %%
tickers = get_tickers()
tick = 24
cryptos = ideals.by_momentum_oscilator(tickers, "1h", tick)
for ticker, data in cryptos:
    print(ticker)
    plot_momentum(data, tick)
# Out:
# BTCUSDT
# SOLUSDT
# LINKUSDT

# %%
data = get_data_as_df("ETHUSDT","1h")

# %%
oscilator = momentum_oscilator(data, 24)
oscilator.tail()
x = data["datetime"]
y = oscilator
plt.figure(1, figsize=[15,6])
plt.plot(x,y)
plt.plot(x, [1 for x in range(0, len(y))])
