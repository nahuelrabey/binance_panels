# %%
from plot import plot_emas, plot_momentum_oscilators , plot_momentum
from main import batch_create_momentum_oscilators, batch_create_emas, get_data_as_df

# %%
data = get_data_as_df("MATICUSDT", "1w")
ticks = [10,30,60]
data = batch_create_emas(data, ticks)
data = batch_create_momentum_oscilators(data, ticks)
plot_emas(data, ticks)
plot_momentum_oscilators(data,ticks)

# %%
data = get_data_as_df("MATICUSDT", "1d")
ticks = [10,30,60]
data = batch_create_emas(data, ticks)
data = batch_create_momentum_oscilators(data, ticks)
plot_emas(data, ticks)
plot_momentum_oscilators(data,ticks)

# %%
data.columns
# Out:
# Index(['OpenTime', 'Open', 'High', 'Low', 'Close', 'Volume', 'CloseTime',
#        'datetime', '10_ema', 'delta_10_ema', '30_ema', 'delta_30_ema',
#        '60_ema', 'delta_60_ema', '10_momentum', '30_momentum', '60_momentum'],
#       dtype='object')

# %%
data = get_data_as_df("MATICUSDT", "1h")
ticks = [10,30,60]
data = batch_create_emas(data, ticks)
data = batch_create_momentum_oscilators(data, ticks)
plot_emas(data, ticks)
plot_momentum_oscilators(data,ticks)
