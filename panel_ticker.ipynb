# %%
from analyse import transform, data, plot

# %%
df = data.get_binance_candlestick("MATICUSDT", "1w")
ticks = [10,30,60]
transform.batch_insert_ema(df, ticks)
transform.batch_insert_momentum_oscilator(df, ticks)
plot.emas(df, ticks)
plot.momentum_oscilators(df,ticks)

# %%
df = data.get_binance_candlestick("MATICUSDT", "1d")
ticks = [10,30,60]
transform.batch_insert_ema(df, ticks)
transform.batch_insert_momentum_oscilator(df, ticks)
plot.emas(df, ticks)
plot.momentum_oscilators(df,ticks)

# %%
df = data.get_binance_candlestick("MATICUSDT", "1h")
ticks = [10,30,60]
transform.batch_insert_ema(df, ticks)
transform.batch_insert_momentum_oscilator(df, ticks)
plot.emas(df, ticks)
plot.momentum_oscilators(df,ticks)
